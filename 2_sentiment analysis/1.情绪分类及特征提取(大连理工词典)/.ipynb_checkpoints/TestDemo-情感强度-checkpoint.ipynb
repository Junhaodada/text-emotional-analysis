# %%
import pandas as pd
import jieba
import time


#获取数据集
f= open('庆余年220.csv',encoding='utf8')
weibo_df=pd.read_csv(f)
# print(weibo_df.head())

# %%
df=pd.read_excel('大连理工大学中文情感词汇本体NAU.xlsx')
df = df[['词语', '词性种类', '词义数', '词义序号', '情感分类', '强度', '极性']]
df.head()
# Out:
#    词语  词性种类  词义数  词义序号 情感分类  强度  极性
# 0  脏乱   adj  1.0   1.0   NN   7   2
# 1  糟报   adj  1.0   1.0   NN   5   2
# 2  早衰   adj  1.0   1.0   NE   5   2
# 3  责备  verb  1.0   1.0   NN   5   2
# 4  贼眼  noun  1.0   1.0   NN   5   2

# %%
qd0=[]
qd1=[]
qd2=[]
qd3=[]
qd4=[]
qd5=[]
qd6=[]
qd7=[]
qd8=[]
qd9=[]

for idx,row in df.iterrows():
    if row['强度'] in [0] :
        qd0.append(row['词语'])
    if row['强度'] in [1]:
        qd1.append(row['词语'])
    if row['强度'] in [2]:
        qd2.append(row['词语'])
    if row['强度'] in [3]:
        qd3.append(row['词语'])
    if row['强度'] in [4]:
        qd4.append(row['词语'])
    if row['强度'] in [5]:
        qd5.append(row['词语'])
    if row['强度'] in [6]:
        qd6.append(row['词语'])
    if row['强度'] in [7]:
        qd7.append(row['词语'])
    if row['强度'] in [8]:
        qd8.append(row['词语'])
    if row['强度'] in [9]:
        qd9.append(row['词语'])

print(qd0)
print(qd1)
# Out:
# ['依违']
# ['温淑', '见闻', '救亡', '据实', '险峭', '寸草不生', '灰蒙蒙', '安好', '安泰', '彪壮', '不动摇', '不泄气', '高深莫测', '强势', '浅显', '起眼儿', '溽热', '温顺', '束身自修', '温软', '可口', '娴静', '健美', '勤勉', '严明', '幽灵', '臭架子', '苟延残喘', '复辟', '看轻', '嘈杂', '犯愁', '颓然', '疑念', '将就', '涵容', '醋意', '忧人发迹怕自穷', '田里的蚯蚓－满肚疑', '口快心直', '称体裁衣', '刚克柔克', '唱筹量沙', '智者千虑，必有一失', '同归于尽', '三对六面', '先天不足', '道高一尺，魔高一仗', '善气迎人', '立锥之地', '顾名思义', '靠天吃饭', '强龙不压地头蛇', '草衣木食', '等米下锅', '利息秋毫', '关门闭户', '反客为主', '凤冠霞帔', '紧行无好步', '粗服乱头', '姗姗来迟', '何其相似乃尔', '尺布斗栗', '漏泄春光', '摇旗打鼓', '欢喜冤家', '金石交', '笙磬同音', '竹马之好', '赤身露体', '格物穷理', '追本穷源', '流言止于智者', '南征北战', '浑水摸鱼', '猎取', '擅自', '犯疑心病', '闲散', '盲用', '耍滑头', '摆款儿', '国威', '翠蓝', '存问', '黛紫', '叮咛', '后门', '虎口', '毁约', '拘牵', '洞究', '宽纵', '放达', '富源', '落套', '没样儿', '贯彻', '回归', '活溜', '求全', '息事宁人', '心虚', '平缓', '零星', '解决', '兼顾', '净化', '废旧', '若明若暗', '发人深思', '属实', '侧重', '慰劳', '放松', '平淡', '合意', '振作', '雪白', '人地生疏', '叹气', '短暂', '看不惯', '邪行', '可笑', '惘然', '心浮', '发急', '拔十得五', '方以类聚', '人非圣贤，孰能无过', '不见经传', '覆车之鉴', '悬崖勒马', '穷鸟入怀', '二旬九食', '据理力争', '八方呼应', '遥相应和', '刮肠洗胃', '知过必改', '天壤王朗', '水至清则无鱼', '泛泛之交', '峨冠博带', '粉白黛黑', '格物致知', '反间之计', '兵在精而不在多', '触类旁通', '怀铅提椠', '蒙蔽', '冷若冰霜', '嫌疑犯', '左顾右盼', '娇痴', '光秃秃', '渺小', '迟迟', '滞后', '次等', '半疯儿', '卑微', '秕糠', '驳杂', '怕生', '扬扬得意', '宽松', '称臣', '吹拂', '国花', '酣然', '含蕴', '翻版', '浮礼', '辞华', '翠微', '荡荡', '德泽', '点题', '叮嘱', '豪绅', '灰色', '洞烛', '端然', '飞翔', '改造', '更始', '攻陷', '共识', '翰墨', '蓬乱', '起意', '红豆', '互惠', '回天', '穷寇', '任情', '和好', '劳驾', '一视同仁', '抚慰', '大户', '雾里看花', '飞快', '稳定', '无限', '近水楼台先得月', '平稳', '美言', '迷途知返', '听从', '一如既往', '阔气', '涤荡', '差事', '标准', '简要', '盈余', '日以继夜', '冷峭', '差点儿', '轻飘', '低价位', '千变万化', '同等重要', '小国寡民', '援救', '皑皑', '帮教', '自言自语', '不可偏废', '敏感', '实际', '即席', '揭晓', '膀阔腰圆', '迷离扑朔', '浅近', '人各有志', '大处落墨', '茅室蓬户', '清寒', '教育', '地主', '照耀', '警省', '敬辞', '病殃殃', '险毒', '不疼不痒', '残破', '锋芒毕露', '挂名', '灰沉沉', '出身名门', '滴水不漏', '多情善感', '没有勇气', '轻淡', '光灿', '好玩儿', '合乎逻辑', '事关重大', '甲等', '虎不食子', '束身自好', '绽放', '暖融融', '居高不下', '宽心', '和蔼可亲', '驰念', '扼要', '湛蓝', '从紧', '抢手', '挂气', '苦涩', '抱委屈', '孤立', '吃了黄连对人说－诉苦', '慑服', '勾引', '含沙射影', '小看', '脸皮厚', '拗口', '担忧', '异味', '委靡', '扫兴', '絮烦', '难堪', '烦忧', '乘兴而来，败兴而归', '费力', '别嘴', '腆颜', '愧悔', '自省', '激切', '恭维', '尺短寸长', '义不容辞', '磨砖成镜', '逆水行舟', '险阻艰难', '韬光养晦', '恐后无凭', '避实就虚', '忍辱含垢', '蓬户筚门', '守经达权', '桃代李僵', '一得之功', '耳闻不如目见', '力争经营', '围魏救赵', '大腹便便', '困而学之', '迁延过时', '情窦初开', '道义之交', '深情厚谊', '一丝不挂', '须眉交白', '切磋琢磨', '研核是非', '荆钗布裙', '一得之愚', '后果', '堕落', '每况愈下', '明枪暗箭', '大惊小怪', '讽刺', '笼统', '偏僻', '事不关己', '模模糊糊', '耍花腔', '无理', '名过其实', '白字', '胆怯', '调皮', '短气', '粹集', '存候', '坏话', '阔绰', '空耗', '溃乱', '督师', '掠取', '没趣', '名利', '根绝', '攻破', '鼓动', '排外', '悍勇', '合理化', '红旗', '洪流', '活动家', '亲谊', '清淡', '和平', '单薄', '险要', '缓和', '轻易', '窄小', '潺潺', '回报', '纷繁', '讨价还价', '施舍', '莽苍', '模糊', '光怪陆离', '并进', '平衡', '抢占', '轻装', '扶持', '衰退', '笑话', '窟窿', '大爷', '区区', '十足', '好人', '见世面', '教坛', '锦缎', '揭幕', '敬酒', '病恹恹', '哀婉', '津润', '崭齐', '旌麾', '儆醒', '救急', '据理', '残破不全', '灰茫茫', '面有愠色', '割席断交', '久战沙场', '从权', '大而全', '心慕手追', '低调', '春秋笔法', '端端正正', '漫不经意', '内幕', '迷宫般', '拆烂污', '黑话', '散乱', '拿捏', '荷花', '护航', '高纯', '高深', '光灿灿', '滚瓜烂熟', '好心肠', '合口味', '鹤发童颜', '树叶茂盛', '守法', '滑不唧溜', '花絮', '筋道', '谨言慎行', '细瘦', '浅易', '手下留情', '面善', '潮呼呼', '四平八稳', '赘述', '珍禽', '柔媚', '从心所欲', '不无道理', '莽莽苍苍', '想开', '和悦', '傲然', '暖乎乎', '关切', '体谅', '气势', '冉冉', '宝刀', '保卫', '触目兴叹', '艰难险阻', '负气', '气呼呼', '苦脸', '盛筵难再', '流言蜚语', '小瞧', '厚脸皮', '挖苦', '白区', '担心', '愁容', '惆怅', '败兴', '疑虑', '乏力', '不问不界', '费劲', '醋心', '野心', '百里之才', '虎狼之穴', '三曹对案', '责有攸归', '直言尽意', '杀鸡饮黍', '柔心弱骨', '先入之见', '公诸同好', '累块积苏', '穷阎漏屋', '耳根清静', '浪迹浮踪', '辩才无碍', '披沙拣金', '大而化之', '如醉方醒', '不名一钱', '兵戎相见', '顺水人情', '才识过人', '见可而进', '情有可原', '啸聚山林', '耸壑昂霄', '先声后实', '雄赳赳，气昂昂', '金兰契友', '声气相投', '至亲好友', '褒衣博带', '默默无闻', '眉眼高低', '耳闻是虚，眼见是实', '亲临其境', '知鱼之乐', '战胜攻取', '闳中肆外', '卑之无甚高论', '串通', '滥用', '连篇累牍', '肆意', '明争暗斗', '怪癖', '圆滑', '破罐破摔', '激进', '螳臂当车', '平板', '谨小慎微', '无味', '粗枝大叶', '夸大', '反常', '强硬', '讥讽', '玩花样', '沧海一粟', '生拉硬拽', '言行不一', '隐晦', '摆份儿', '好离好散', '秋水伊人', '音容笑貌', '忍让', '畏葸', '倔强', '寂静', '嗔怒', '敌国', '春色', '蹈袭', '国故', '国术', '雕饰', '赌博', '仿冒', '分肥', '浮华', '粹聚', '存抚', '答谢', '黛绿', '得劲', '底蕴', '叠翠', '后患', '胡诌', '混事', '假球', '阔少', '谰 ...

# %%
#添加自定义词典和停用词
#jieba.load_userdict("user_dict.txt")
stop_list = pd.read_csv('stop_words.txt',
                        engine='python',
                        encoding='utf-8',
                        delimiter="\n",
                        names=['t'])

#获取重命名t列的值
stop_list = stop_list['t'].tolist()

def txt_cut(juzi):
    return [w for w in jieba.lcut(juzi) if w not in stop_list]     #可增加len(w)>1

# %%
def emotion_caculate(text):
    qd0=0
    qd1=0
    qd2=0
    qd3=0
    qd4=0
    qd5=0
    qd6=0
    qd7=0
    qd8=0
    qd9=0
    
    qd0_list = []
qd1_list = []
qd2_list = []
qd3_list = []
qd4_list = []
qd5_list = []
qd6_list = []
qd7_list = []
qd8_list = []
qd9_list = []
